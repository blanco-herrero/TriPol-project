# %% [markdown]
# <a href="https://colab.research.google.com/github/blanco-herrero/TriPol-project/blob/main/David_toxicity_pruebas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install google-api-python-client

# %%
from googleapiclient import discovery
import json
import pandas as pd
import time

# %%
# !wc SpainMedia.txt
# Out:
#    23679 2063583 12749989 SpainMedia.txt

# %%
# !wc SpainTwitter.txt
# Out:
#   100328 2630916 18993010 SpainTwitter.txt

# %%
df = pd.read_csv('SpainTwitter.txt', sep='\t')
df
# Out:
#                                                     text
# 0       Me hace mucha ilusión acompañar este sábado en...
# 1       Visitando o barrio de #Recimil en Ferrol. Un B...
# 2       Hoxe andaremos por #Carballo  #carballomola ht...
# 3       <U+0001F4FA> A TVG emite hoxe ás 10h da mañá, ...
# 4       @PeteiroG @obloque @aKollontai @ManuLourenzo @...
# ...                                                   ...
# 100324  Australia: Djokovic consigue una prórroga a su...
# 100325  Decenas de manifestantes mueren a manos de la ...
# 100326  La Asamblea Nacional de Francia aprueba el pas...
# 100327  EEUU cumple un año del asalto al Capitolio con...
# 100328  Ilusión sin caramelos: vuelven las cabalgatas ...
#
# [100329 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['text '], dtype='object')

# %%
texts2 = df[["text"]].to_dict("records")
texts2
# Out:
# [{'text': 'La acusación de transfobia a cualquier apunte crítico a la ley trans, una ley que aún no se conoce, pero que parece ser muy similar a otras que se han aprobado en varias comunidades autónomas, no es admisible. Solo puede entenderse este insulto en el marco del clima ideológico de criminalización del contrario que se ha ido instalando en las sociedades democráticas al calor del populismo de extrema derecha. Cuando los insultos sustituyen a los argumentos estamos en los prolegómenos del fascismo. No voy a hablar en este artículo sobre los desacuerdos que tengo con la ley, que los tengo, como los tengo con otras muchas leyes. Parto del supuesto de que la comunidad trans reclama los derechos que estima que le corresponde, como también parto del supuesto de que el feminismo defiende los derechos de las mujeres como ha hecho durante tres siglos.'},
# ...

# %%
text1 = { 'text': 'Maldito negro de mierda'}

# %%
texts = ({'text': 'Maldito negro de mierda'} , {'text': 'Bello'} )
type(texts)
# Out:
# tuple

# %%
API_KEY = 'AIzaSyDKAw6FHIJ6x9fgyB_JcrTBkKlzkh0Pk3I'
#API_KEY: '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'

# %%
def toxicity(text):
  client = discovery.build(
    "commentanalyzer",
    "v1alpha1",
    developerKey=API_KEY,
    discoveryServiceUrl="https://commentanalyzer.googleapis.com/$discovery/rest?version=v1alpha1",
  )

  analyze_request = {
    'comment': text,
    'requestedAttributes': {'TOXICITY': {}, 'SEVERE_TOXICITY': {}, 'IDENTITY_ATTACK': {}, 'INSULT': {}, 'PROFANITY': {}, 'THREAT': {}}
  }

  response = client.comments().analyze(body=analyze_request).execute()
  return json.dumps(response)

# %%
json.loads(toxicity(text1))['attributeScores']['SEVERE_TOXICITY']['spanScores'][0]['score']['value']
# Out:
# 0.99046606

# %%
t_sleep = 6

for key in texts2:
  try:
    TOXICITY = json.loads(toxicity(key))['attributeScores']['TOXICITY']['spanScores'][0]['score']['value']
    SEVERE_TOXICITY = json.loads(toxicity(key))['attributeScores']['SEVERE_TOXICITY']['spanScores'][0]['score']['value']
    IDENTITY_ATTACK = json.loads(toxicity(key))['attributeScores']['IDENTITY_ATTACK']['spanScores'][0]['score']['value']
    INSULT = json.loads(toxicity(key))['attributeScores']['INSULT']['spanScores'][0]['score']['value']
    PROFANITY = json.loads(toxicity(key))['attributeScores']['PROFANITY']['spanScores'][0]['score']['value']
    THREAT = json.loads(toxicity(key))['attributeScores']['THREAT']['spanScores'][0]['score']['value']
    print(key['text'], "\t", TOXICITY, '\t', SEVERE_TOXICITY, '\t', IDENTITY_ATTACK, '\t', INSULT, '\t', PROFANITY, "\t", THREAT )
    time.sleep( t_sleep )

  except Exception as e:
    print("Exception occurred for value '': "+ repr(e))

# %%
import sys

orig_stdout = sys.stdout
f = open('results_spain_media.txt', 'w')
sys.stdout = f

t_sleep = 6

for key in texts2:
  try:
    TOXICITY = json.loads(toxicity(key))['attributeScores']['TOXICITY']['spanScores'][0]['score']['value']
    SEVERE_TOXICITY = json.loads(toxicity(key))['attributeScores']['SEVERE_TOXICITY']['spanScores'][0]['score']['value']
    IDENTITY_ATTACK = json.loads(toxicity(key))['attributeScores']['IDENTITY_ATTACK']['spanScores'][0]['score']['value']
    INSULT = json.loads(toxicity(key))['attributeScores']['INSULT']['spanScores'][0]['score']['value']
    PROFANITY = json.loads(toxicity(key))['attributeScores']['PROFANITY']['spanScores'][0]['score']['value']
    THREAT = json.loads(toxicity(key))['attributeScores']['THREAT']['spanScores'][0]['score']['value']
    print(key['text'], "\t", TOXICITY, '\t', SEVERE_TOXICITY, '\t', IDENTITY_ATTACK, '\t', INSULT, '\t', PROFANITY, "\t", THREAT )
    time.sleep( t_sleep )


  except Exception as e:
    print(key['text'], "\t", 'null', '\t', 'null', '\t', 'null', '\t', 'null', '\t', 'null', "\t", 'null' )


sys.stdout = orig_stdout
f.close()

# %%
# !wc results_spain_media_parcial.txt

# %%
colnames = ['text', 'TOXICITY', 'SEVERE_TOXICITY', 'IDENTITY_ATTACK', 'INSULT', 'PROFANITY', 'THREAT']
df2 = pd.read_csv('results2.txt', sep='\t', names=colnames, header=None)
df2
# Out:
#                                                   text        TOXICITY  \
# 0    #ELECCIONESCOLOMBIA. Como delegados de la Misi...    0.004026131
# 1    Hay que decirlo: que alguien como @FranciaMarq...     0.02929751
# 2    En su primer discurso como Presidente electo @...    0.094410956
# 3    Nota de Rafael Ramírez/ @RRamirezVEDía históri...   0.0066292323
# 4    #Graficos 📊📈    En su tercer intento, Gustavo ...     0.09870692
# ..                                                 ...             ...
# 203  @Enriquerod70 Que bueno que abandones el barco...       0.355017
# 204  Que produjo la inexplicable caída de #Biden al...     0.02929751
# 205  tenemos suficiente normatividad para proteger ...    0.010342991
# 206  Cuando vuelves y lees la propuesta de financia...     0.00860759
# 207  La participación del 58% en la segunda vuelta ...    0.016521018
#
#     SEVERE_TOXICITY IDENTITY_ATTACK         INSULT       PROFANITY  \
# ...

# %%
from google.colab import files
files.download('results2.txt')

# %%
dfNew = df.merge(df2, left_index=True, right_index=True,
                 how='outer', suffixes=('', '_y'))

dfNew.drop(dfNew.filter(regex='_y$').columns, axis=1, inplace=True)
dfNew
# Out:
#                author_id         username  author_followers  author_tweets  \
# 0    1468228950723813378  G_PachecoVillar               157            224
# 1              194240654       EnmanuelS7              1715          65780
# 2    1490481570083442697     JuventudesSN              2082            549
# 3    1296402229352595462  VeCriticaSocial                81           2328
# 4               17548080  diarioelheraldo            430039         353487
# ..                   ...              ...               ...            ...
# 203  1002923497029394433  MarcoAu40058423               631           4994
# 204  1149466863287410690      hcs33793062                54           3176
# 205            112929755        tatan6542              1171          78388
# 206            831316723    tupsiquiatraa              1203          19518
# 207            287919893           Paob31              1322          17239
#
# ...

# %%
toxicity(text1)
# Out:
# {
#   "attributeScores": {
#     "SEVERE_TOXICITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 23,
#           "score": {
#             "value": 0.99046606,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.99046606,
#         "type": "PROBABILITY"
#       }
#     },
#     "IDENTITY_ATTACK": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 23,
#           "score": {
#             "value": 1,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 1,
#         "type": "PROBABILITY"
#       }
#     },
#     "PROFANITY": {
#       "spanScores": [
#         {
#           "begin": 0,
#           "end": 23,
#           "score": {
#             "value": 0.9918269,
#             "type": "PROBABILITY"
#           }
#         }
#       ],
#       "summaryScore": {
#         "value": 0.9918269,
# ...
